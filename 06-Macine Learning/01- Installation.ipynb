# %% [markdown]
# # Steps:
# 1. Create a new Conda Environment; 'python_ml'
# 2. Install the following packages:
#     1. pandas
#     2. scikit-learn
#     3. numpy
#     4. matplotlib
#     5. seaborn
#     6. jupyter
#     7. plotly
#     8. scipy
#     9. openpyxl

# %%
# Out:
# ...
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/5.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/5.0 MB 929.6 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.5/5.0 MB 929.6 kB/s eta 0:00:05
#    ------ --------------------------------- 0.8/5.0 MB 907.1 kB/s eta 0:00:05
#    -------- ------------------------------- 1.0/5.0 MB 967.3 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.3/5.0 MB 1.0 MB/s eta 0:00:04
#    ------------ --------------------------- 1.6/5.0 MB 1.0 MB/s eta 0:00:04
#    -------------- ------------------------- 1.8/5.0 MB 1.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.1/5.0 MB 1.1 MB/s eta 0:00:03
#    ------------------ --------------------- 2.4/5.0 MB 1.1 MB/s eta 0:00:03
# ...
